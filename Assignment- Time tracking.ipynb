# %% [markdown]
# # Programming Project 1 analysis using EDA tools
# - Name: Reese Bottorff
# - Date: 10-03-2023
# - Version: DS_160

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime as dt

# %%
df=pd.read_csv("DS Time log.csv")

# %%
df.head()
# Out:
#   Initial    Date    Course_ID  Time (M)  \
# 0      RB  9/5/23     BIOL_115        50
# 1      RB  9/5/23       DS_160        75
# 2      RB  9/5/23     MKTG_305        75
# 3      RB  9/5/23  BIOL_115Lab        60
# 4      RB  9/6/23     COMM_200        50
#
#                                          Summary
# 0  Had a quiz and completed an in class activity
# 1               Completed an in class assignment
# 2                         Lecture over Chapter 4
# 3                          Looked at cheek cells
# 4                        Lecture over Chapter 15

# %% [markdown]
# ### Investigate your dataset

# %%
df.head()
# Out:
#   Initial       Date    Course_ID  Time (M)  \
# 0      RB 2023-09-05     BIOL_115        50
# 1      RB 2023-09-05       DS_160        75
# 2      RB 2023-09-05     MKTG_305        75
# 3      RB 2023-09-05  BIOL_115Lab        60
# 4      RB 2023-09-06     COMM_200        50
#
#                                          Summary   day_name  day
# 0  Had a quiz and completed an in class activity    Tuesday    1
# 1               Completed an in class assignment    Tuesday    2
# 2                         Lecture over Chapter 4    Tuesday    3
# 3                          Looked at cheek cells    Tuesday    4
# 4                        Lecture over Chapter 15  Wednesday    5

# %%
df.tail()
# Out:
#    Initial       Date    Course_ID  Time (M)  \
# 60      RB 2023-10-02     FINA_315        75
# 61      RB 2023-10-03     BIOL_115        50
# 62      RB 2023-10-03       DS_160        75
# 63      RB 2023-10-03     MKTG_305        75
# 64      RB 2023-10-03  BIOL_115Lab        60
#
#                                    Summary day_name  day
# 60                  Lecture over Chapter 5   Monday   61
# 61                        Genetics lecture  Tuesday   62
# 62  Finish Seaborn and in class assignment  Tuesday   63
# 63                      Review for Midterm  Tuesday   64
# 64                        Lab over condoms  Tuesday   65

# %%
df.sample(5)
# Out:
#    Initial       Date Course_ID  Time (M)                      Summary  \
# 40      RB 2023-09-21  BIOL_115        50  Lecture over Photosynthesis
# 37      RB 2023-09-20  COMM_200        50       Lecture over Chapter 5
# 44      RB 2023-09-25  COMM_200        50     Finish Chapter 5 lecture
# 25      RB 2023-09-14    DS_160        75       Finish Pandas notebook
# 56      RB 2023-09-28  MKTG_305        75       Lecture over Chapter 9
#
#      day_name  day
# 40   Thursday   41
# 37  Wednesday   38
# 44     Monday   45
# 25   Thursday   26
# 56   Thursday   57

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x='Course_ID',y='Time (M)',data=df)
df['Course_ID'].describe()
# Out:
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# count           65
# unique           6
# top       COMM_200
# freq            13
# Name: Course_ID, dtype: object

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days
# ![image.png](attachment:image.png)

# %%
df['Date']=pd.to_datetime(df['Date'])
df['day_name']=df['Date'].dt.day_name()
df['day']=range(1,len(df)+1)
df.head()
# Out:
# /var/folders/q_/k5zmb9hs78n7mhfrwqvnb1fh0000gn/T/ipykernel_70263/1131335767.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']=pd.to_datetime(df['Date'])
#   Initial       Date    Course_ID  Time (M)  \
# 0      RB 2023-09-05     BIOL_115        50
# 1      RB 2023-09-05       DS_160        75
# 2      RB 2023-09-05     MKTG_305        75
# 3      RB 2023-09-05  BIOL_115Lab        60
# 4      RB 2023-09-06     COMM_200        50
#
#                                          Summary   day_name  day
# 0  Had a quiz and completed an in class activity    Tuesday    1
# 1               Completed an in class assignment    Tuesday    2
# 2                         Lecture over Chapter 4    Tuesday    3
# 3                          Looked at cheek cells    Tuesday    4
# 4                        Lecture over Chapter 15  Wednesday    5

# %% [markdown]
# # Add Histogram and Bar Chart

# %%
sns.barplot(x='Course_ID',y='Time (M)',data=df,ci=False)
# Out:
# /var/folders/q_/k5zmb9hs78n7mhfrwqvnb1fh0000gn/T/ipykernel_70263/1718015781.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Course_ID',y='Time (M)',data=df,ci=False)
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.histplot(x='Course_ID',y='Time (M)',data=df)
# Out:
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# This graph shows that I spend the most time in/working on Fina_315

# %% [markdown]
# This graph also shows that I spend the least time in/working on Comm_200

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see how often you engaged in each.

# %%
df['Course_ID'].value_counts()
# Out:
# Course_ID
# COMM_200       13
# DS_160         12
# MKTG_305       12
# FINA_315       12
# BIOL_115       10
# BIOL_115Lab     6
# Name: count, dtype: int64

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='day',y='Time (M)',data=df,hue='Course_ID')
# Out:
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/reesebottorff/opt/anaconda3/envs/DS_160/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.head()
# Out:
#   Initial       Date    Course_ID  Time (M)  \
# 0      RB 2023-09-05     BIOL_115        50
# 1      RB 2023-09-05       DS_160        75
# 2      RB 2023-09-05     MKTG_305        75
# 3      RB 2023-09-05  BIOL_115Lab        60
# 4      RB 2023-09-06     COMM_200        50
#
#                                          Summary   day_name  day
# 0  Had a quiz and completed an in class activity    Tuesday    1
# 1               Completed an in class assignment    Tuesday    2
# 2                         Lecture over Chapter 4    Tuesday    3
# 3                          Looked at cheek cells    Tuesday    4
# 4                        Lecture over Chapter 15  Wednesday    5

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
bio=df.query('Course_ID=="BIOL_115"')['Time (M)'].sum()
print(f'Total time spent on BIOL_115:', bio)
# Out:
# Total time spent on BIOL_115: 550

# %%
ds=df.query('Course_ID=="DS_160"')['Time (M)'].sum()
print(f'Total time spent on DS_160:', ds)
# Out:
# Total time spent on DS_160: 825

# %%
mk=df.query('Course_ID=="MKTG_305"')['Time (M)'].sum()
print(f'Total time spent on MKTG_305:', mk)
# Out:
# Total time spent on MKTG_305: 730

# %%
biol=df.query('Course_ID=="BIOL_115Lab"')['Time (M)'].sum()
print(f'Total time spent on BIOL_115Lab:', biol)
# Out:
# Total time spent on BIOL_115Lab: 315

# %%
com=df.query('Course_ID=="COMM_200"')['Time (M)'].sum()
print(f'Total time spent on COMM_200:', com)
# Out:
# Total time spent on COMM_200: 605

# %%
fin=df.query('Course_ID=="FINA_315"')['Time (M)'].sum()
print(f'Total time spent on FINA_315:', fin)
# Out:
# Total time spent on FINA_315: 950

# %% [markdown]
# This shows that I spent the most time on FINA_315 and the least time on BIOL_115Lab

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less.
# ![image.png](attachment:image.png)

# %%
heat_map=df[['day','Time (M)']].corr(method='pearson')
cols=['day','time']
sns.heatmap(heat_map, xticklabels=cols, yticklabels=cols, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# This shows I spend less time on my courses
